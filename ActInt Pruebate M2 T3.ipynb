# %% [markdown]
# #Actividad de Integración Pruebate Módulo 2 Tema 3

# %%
import pandas as pd
pd.options.display.max_columns = 12

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %% [markdown]
# 1.	Crear un dataframe que contenga 5 registros de deportistas famosos con su nombre y el deporte que practican.

# %%
deportistas = pd.DataFrame({
   "Nombre": pd.Series(['Micheal Jordan', 'Lionel Messi', 'Tom Brady', 'Serena Williams']),
   "Deporte": pd.Series(['Baloncesto', 'Fútbol', 'Fútbol Americanco', 'Tenis'])
})
deportistas
# Out:
#             Nombre            Deporte
# 0   Micheal Jordan         Baloncesto
# 1     Lionel Messi             Fútbol
# 2        Tom Brady  Fútbol Americanco
# 3  Serena Williams              Tenis

# %% [markdown]
# 2.	Crear una serie con la edad de los deportistas y agregarla al dataframe.

# %%
edad = pd.Series([58, 33, 43, 39])
print('Edad: \n', edad)
deportistas['Edad'] = edad
print('Deportistas: \n', deportistas)
# Out:
# Edad:
#  0    58
# 1    33
# 2    43
# 3    39
# dtype: int64
# Deportistas:
#              Nombre            Deporte  Edad
# 0   Micheal Jordan         Baloncesto    58
# 1     Lionel Messi             Fútbol    33
# 2        Tom Brady  Fútbol Americanco    43
# 3  Serena Williams              Tenis    39

# %% [markdown]
# 3.	Leer el archivo que se encuentra en la siguiente liga:

# %%
tweets = pd.read_csv('/content/drive/MyDrive/Colab Notebooks/TLG/vaccination_tweets.csv')
tweets
# Out:
#                 id             user_name  ... favorites is_retweet
# 0     1.340000e+18            Rachel Roh  ...         0      False
# 1     1.340000e+18           Albert Fong  ...         1      False
# 2     1.340000e+18              eli🇱🇹🇪🇺👌  ...         0      False
# 3     1.340000e+18         Charles Adler  ...      2129      False
# 4     1.340000e+18  Citizen News Channel  ...         0      False
# ...            ...                   ...  ...       ...        ...
# 4275  1.350000e+18          Cate Cammack  ...         8      False
# 4276  1.350000e+18        SUR in English  ...         2      False
# 4277  1.350000e+18       Melissa coleman  ...         0      False
# 4278  1.350000e+18          The Insider🦉  ...         0      False
# 4279  1.350000e+18         Dr Ai Lyn Tan  ...         5      False
#
# [4280 rows x 16 columns]

# %% [markdown]
# 4.	Mostrar los primeros 7 registros

# %%
tweets.head(7)
# Out:
#              id             user_name  ... favorites is_retweet
# 0  1.340000e+18            Rachel Roh  ...         0      False
# 1  1.340000e+18           Albert Fong  ...         1      False
# 2  1.340000e+18              eli🇱🇹🇪🇺👌  ...         0      False
# 3  1.340000e+18         Charles Adler  ...      2129      False
# 4  1.340000e+18  Citizen News Channel  ...         0      False
# 5  1.340000e+18                   Dee  ...         0      False
# 6  1.340000e+18     Gunther Fehlinger  ...         4      False
#
# [7 rows x 16 columns]

# %% [markdown]
# 5.	Mostrar los últimos 4 registros

# %%
tweets.tail(4)
# Out:
#                 id        user_name  ... favorites is_retweet
# 4276  1.350000e+18   SUR in English  ...         2      False
# 4277  1.350000e+18  Melissa coleman  ...         0      False
# 4278  1.350000e+18     The Insider🦉  ...         0      False
# 4279  1.350000e+18    Dr Ai Lyn Tan  ...         5      False
#
# [4 rows x 16 columns]

# %% [markdown]
# 6.	Mostrar la estructura del dataframe

# %%
tweets.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4280 entries, 0 to 4279
# Data columns (total 16 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   id                4280 non-null   float64
#  1   user_name         4280 non-null   object
#  2   user_location     3398 non-null   object
#  3   user_description  4009 non-null   object
#  4   user_created      4280 non-null   object
#  5   user_followers    4280 non-null   int64
#  6   user_friends      4280 non-null   int64
#  7   user_favourites   4280 non-null   int64
#  8   user_verified     4280 non-null   bool
#  9   date              4280 non-null   object
#  10  text              4280 non-null   object
#  11  hashtags          3188 non-null   object
#  12  source            4279 non-null   object
#  13  retweets          4280 non-null   int64
#  14  favorites         4280 non-null   int64
#  15  is_retweet        4280 non-null   bool
# ...

# %% [markdown]
# 7.	Elimina del dataframe los tres primeros registros y vuelve a usar la función head para mostrar los primeros 5 registros

# %%
tweets = tweets.drop([0, 1, 2], axis=0)
tweets.head(5)
# Out:
#              id             user_name  ... favorites is_retweet
# 3  1.340000e+18         Charles Adler  ...      2129      False
# 4  1.340000e+18  Citizen News Channel  ...         0      False
# 5  1.340000e+18                   Dee  ...         0      False
# 6  1.340000e+18     Gunther Fehlinger  ...         4      False
# 7  1.340000e+18   Dr.Krutika Kuppalli  ...        22      False
#
# [5 rows x 16 columns]

# %% [markdown]
# 8.	Elimina del dataframe las columnas: user_created y user_description y vuelve a utilizar la función tail para mostrar los últimos 3 registros.

# %%
tweets = tweets.drop(['user_created', 'user_description'], axis=1)
tweets.tail(3)
# Out:
#                 id        user_name  ... favorites  is_retweet
# 4277  1.350000e+18  Melissa coleman  ...         0       False
# 4278  1.350000e+18     The Insider🦉  ...         0       False
# 4279  1.350000e+18    Dr Ai Lyn Tan  ...         5       False
#
# [3 rows x 14 columns]

# %% [markdown]
# 9.	Agrega una columna llamada revisado con el valor True para todos los registros y muestra los primeros dos registros

# %%
tweets['revisado'] = True
tweets.head(2)
# Out:
#              id             user_name  ... is_retweet  revisado
# 3  1.340000e+18         Charles Adler  ...      False      True
# 4  1.340000e+18  Citizen News Channel  ...      False      True
#
# [2 rows x 15 columns]

# %% [markdown]
# 10.	Almacenar el nuevo dataframe en:
#
# > a.	Un archivo separado por comas llamado “tweets_revisados.csv”
#
# > b.	Un archivo de Excel llamado “tweets_procesados.xlsx”

# %%
tweets.to_csv('/content/drive/MyDrive/Colab Notebooks/TLG/tweets_revisados.cvs')
tweets.to_excel('/content/drive/MyDrive/Colab Notebooks/TLG/tweets_procesados.xlsx')
