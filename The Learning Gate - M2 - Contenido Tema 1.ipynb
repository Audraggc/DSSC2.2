# %% [markdown]
# #Contenido TLG Módulo 2 Tema 1

# %% [markdown]
# ##Subtema 2 Verificando e instalando una plataforma

# %% [markdown]
# **Verificando que la plataforma se encuentre instalada (si está instalada)**

# %%
# !pip show numpy
# Out:
# Name: numpy
# Version: 1.19.5
# Summary: NumPy is the fundamental package for array computing with Python.
# Home-page: https://www.numpy.org
# Author: Travis E. Oliphant et al.
# Author-email: None
# License: BSD
# Location: /usr/local/lib/python3.7/dist-packages
# Requires:
# ...

# %% [markdown]
# **Verificando que la plataforma se encuentre instalada (no está instalada)**

# %%
# !pip show django
# Out:
# WARNING: Package(s) not found: django

# %% [markdown]
# **Instalando una plataforma (exito)**

# %%
# !pip install django
# Out:
# ...
#      |████████████████████████████████| 7.9MB 5.4MB/s
# ...

# %% [markdown]
# **Instalando una plataforma (fracaso)**

# %%
# !pip install platformvis
# Out:
# ERROR: Could not find a version that satisfies the requirement platformvis (from versions: none)
# ERROR: No matching distribution found for platformvis

# %% [markdown]
# ##Subtema 3 Usando una plataforma

# %% [markdown]
# **Usando la plataforma NumPy**

# %%
import numpy
numpy.zeros(5)
# Out:
# array([0., 0., 0., 0., 0.])

# %% [markdown]
# **Usando una plataforma Pandas con una referencia**

# %%
import pandas as pd
pd.Series([1, 2, 3])
# Out:
# 0    1
# 1    2
# 2    3
# dtype: int64

# %% [markdown]
# **Obteniendo el tipo de dato de la referencia a una plataforma como numpy**

# %%
import numpy as np
type(np)
# Out:
# module

# %% [markdown]
# **Obteniendo el mínimo de una lista de 10 edades generadas de manera aleatoria**

# %%
import numpy as np
rg = np.random.default_rng()
arreglo = rg.integers(100, size=(10))
arreglo.min()
# Out:
# 4
